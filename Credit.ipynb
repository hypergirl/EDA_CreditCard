# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
application_record=pd.read_csv('C:\\Users\\divya.r16\\Documents\\Ineuron\\application_record.csv')

# %%
application_record.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
application_record.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
# Occupation type has null values

application_record.OCCUPATION_TYPE.value_counts()
# Out:
# Laborers                 78240
# Core staff               43007
# Sales staff              41098
# Managers                 35487
# Drivers                  26090
# High skill tech staff    17289
# Accountants              15985
# Medicine staff           13520
# Cooking staff             8076
# Security staff            7993
# Cleaning staff            5845
# Private service staff     3456
# Low-skill Laborers        2140
# Secretaries               2044
# Waiters/barmen staff      1665
# Realty agents             1041
# HR staff                   774
# IT staff                   604
# Name: OCCUPATION_TYPE, dtype: int64

# %%
application_record[application_record.OCCUPATION_TYPE.isna()]
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 7       5008812           F            N               Y             0
# 8       5008813           F            N               Y             0
# 9       5008814           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438549  6840098           F            N               Y             0
# 438550  6840100           F            N               Y             0
# 438551  6840102           F            N               Y             0
# 438552  6840104           M            N               Y             0
# 438555  6842765           F            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
credit_record=pd.read_csv('C:\\Users\\divya.r16\\Documents\\Ineuron\\credit_record.csv')

# %%
credit_record.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
df=application_record.merge(credit_record,on='ID')

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# ...

# %%
df.shape
# Out:
# (777715, 20)

# %%
#Duplicates because every users updated remaining months of loan payment
df.ID.duplicated().sum()
# Out:
# 741258

# %%
df[df.ID.duplicated()]
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# 5       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
# So, we keep only the latest data of the customer

df.drop_duplicates('ID',keep='last',inplace=True)

# %%
df.ID.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (36457, 20)

# %%
741258-36457
# Out:
# 704801

# %%
df.head()
# Out:
#          ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 15  5008804           M            Y               Y             0
# 30  5008805           M            Y               Y             0
# 60  5008806           M            Y               Y             0
# 65  5008808           F            N               Y             0
# 70  5008809           F            N               Y             0
#
#     AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 15          427500.0               Working               Higher education
# 30          427500.0               Working               Higher education
# 60          112500.0               Working  Secondary / secondary special
# 65          270000.0  Commercial associate  Secondary / secondary special
# 70          270000.0  Commercial associate  Secondary / secondary special
#
#       NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
unemployed=df[df.DAYS_EMPLOYED>0]

# %%
unemployed.shape
# Out:
# (6135, 20)

# %%
unemployed.head()
# Out:
#            ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 153   5008812           F            N               Y             0
# 170   5008813           F            N               Y             0
# 187   5008814           F            N               Y             0
# 1270  5008884           F            N               Y             0
# 2529  5008974           F            N               Y             0
#
#       AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 153           283500.0        Pensioner               Higher education
# 170           283500.0        Pensioner               Higher education
# 187           283500.0        Pensioner               Higher education
# 1270          315000.0        Pensioner  Secondary / secondary special
# 2529          112500.0        Pensioner  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
sns.histplot(data=unemployed,x='STATUS')
# Out:
# <AxesSubplot:xlabel='STATUS', ylabel='Count'>

# %% [markdown]
# # So mostly unemployed ppl pay it within a month or they don't take loan

# %%
df.STATUS.value_counts()
# Out:
# 0    21555
# X    14591
# C      302
# 1        8
# 5        1
# Name: STATUS, dtype: int64

# %%
#0: 1-29 days past due 
#1: 30-59 days past due 
#2: 60-89 days overdue 
#3: 90-119 days overdue 
#4: 120-149 days overdue 
#5: Overdue or bad debts, write-offs for more than 150 days 
#C: paid off that month 
#X: No loan for the month

# %%
df.STATUS=np.where((df.STATUS=='1')|(df.STATUS=='2')|(df.STATUS=='3')|(df.STATUS=='5'),1,0)

# %%
employed=df[df.DAYS_EMPLOYED<0]

# %%
sns.histplot(data=employed,x='STATUS')
# Out:
# <AxesSubplot:xlabel='STATUS', ylabel='Count'>

# %% [markdown]
# ### So mostly ppl pay it within a month or they don't take loan

# %%
# Cross tabulation between GENDER and STATUS
CrosstabResult=pd.crosstab(columns=df['CODE_GENDER'],index=df['STATUS'])

# %%
CrosstabResult.plot.bar(rot=1)
# Out:
# <AxesSubplot:xlabel='STATUS'>

# %%
df.CODE_GENDER.value_counts()
# Out:
# F    24430
# M    12027
# Name: CODE_GENDER, dtype: int64

# %% [markdown]
# ### Mostly there are females who take loan

# %%
df.OCCUPATION_TYPE.isna().sum()
# Out:
# 11323

# %%
df.OCCUPATION_TYPE.fillna('Others',inplace=True)

# %%
df.OCCUPATION_TYPE.isna().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                  ID  CNT_CHILDREN  AMT_INCOME_TOTAL    DAYS_BIRTH  \
# count  3.645700e+04  36457.000000      3.645700e+04  36457.000000
# mean   5.078227e+06      0.430315      1.866857e+05 -15975.173382
# std    4.187524e+04      0.742367      1.017892e+05   4200.549944
# min    5.008804e+06      0.000000      2.700000e+04 -25152.000000
# 25%    5.042028e+06      0.000000      1.215000e+05 -19438.000000
# 50%    5.074614e+06      0.000000      1.575000e+05 -15563.000000
# 75%    5.115396e+06      1.000000      2.250000e+05 -12462.000000
# max    5.150487e+06     19.000000      1.575000e+06  -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE    FLAG_PHONE    FLAG_EMAIL  \
# count   36457.000000     36457.0     36457.000000  36457.000000  36457.000000
# mean    59262.935568         1.0         0.225526      0.294813      0.089722
# std    137651.334859         0.0         0.417934      0.455965      0.285787
# ...

# %%
pivot_tb = credit_record.pivot(index = 'ID', columns = 'MONTHS_BALANCE', values = 'STATUS')

# %%
pivot_tb
# Out:
# MONTHS_BALANCE  -60  -59  -58  -57  -56  -55  -54  -53  -52  -51  ...  -9   \
# ID                                                                ...
# 5001711         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 5001712         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    0
# 5001713         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    X
# 5001714         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    X
# 5001715         NaN    X    X    X    X    X    X    X    X    X  ...    X
# ...             ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 5150482         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 5150483         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    X
# 5150484         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    0
# 5150485         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 5150487         NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    C
# ...

# %%
grouped = credit_record.groupby('ID')
### convert credit data to wide format which every ID is a row
pivot_tb = credit_record.pivot(index = 'ID', columns = 'MONTHS_BALANCE', values = 'STATUS')
pivot_tb['open_month'] = grouped['MONTHS_BALANCE'].min() # smallest value of MONTHS_BALANCE, is the month when loan was granted
pivot_tb['end_month'] = grouped['MONTHS_BALANCE'].max() # biggest value of MONTHS_BALANCE, might be observe over or canceling account
pivot_tb['ID'] = pivot_tb.index
pivot_tb = pivot_tb[['ID', 'open_month', 'end_month']]
pivot_tb['window'] = pivot_tb['end_month'] - pivot_tb['open_month'] # calculate observe window
pivot_tb.reset_index(drop = True, inplace = True)
credit = pd.merge(credit_record, pivot_tb, on = 'ID', how = 'left') # join calculated information
credit0 = credit.copy()
credit = credit[credit['window'] > 20] # delete users whose observe window less than 20
credit['status'] = np.where((credit['STATUS'] == '2') | (credit['STATUS'] == '3' )| (credit['STATUS'] == '4' )| (credit['STATUS'] == '5'), 1, 0) # analyze > 60 days past due 
credit['status'] = credit['status'].astype(np.int8) # 1: overdue 0: not
credit['month_on_book'] = credit['MONTHS_BALANCE'] - credit['open_month'] # calculate month on book: how many months after opening account
credit.sort_values(by = ['ID','month_on_book'], inplace = True)

##### denominator
denominator = pivot_tb.groupby(['open_month']).agg({'ID': ['count']}) # count how many users in every month the account was opened
denominator.reset_index(inplace = True)
denominator.columns = ['open_month','sta_sum']

##### ventage table
vintage = credit.groupby(['open_month','month_on_book']).agg({'ID': ['count']}) 
vintage.reset_index(inplace = True)
vintage.columns = ['open_month','month_on_book','sta_sum'] 
vintage['due_count'] = np.nan
vintage = vintage[['open_month','month_on_book','due_count']] # delete aggerate column
vintage = pd.merge(vintage, denominator, on = ['open_month'], how = 'left') # join sta_sum colun to vintage table
vintage
# Out:
#       open_month  month_on_book  due_count  sta_sum
# 0            -60              0        NaN      415
# 1            -60              1        NaN      415
# 2            -60              2        NaN      415
# 3            -60              3        NaN      415
# 4            -60              4        NaN      415
# ...          ...            ...        ...      ...
# 1655         -21             17        NaN      858
# 1656         -21             18        NaN      858
# 1657         -21             19        NaN      858
# 1658         -21             20        NaN      858
# 1659         -21             21        NaN      858
#
# [1660 rows x 4 columns]

# %%
### convert credit data to wide format which every ID is a row
pivot_tb = credit_record.pivot(index = 'ID', columns = 'MONTHS_BALANCE', values = 'STATUS')
pivot_tb['open_month'] = grouped['MONTHS_BALANCE'].min() # smallest value of MONTHS_BALANCE, is the month when loan was granted
pivot_tb['end_month'] = grouped['MONTHS_BALANCE'].max() # biggest value of MONTHS_BALANCE, might be observe over or canceling account
pivot_tb['ID'] = pivot_tb.index
pivot_tb = pivot_tb[['ID', 'open_month', 'end_month']]
pivot_tb['window'] = pivot_tb['end_month'] - pivot_tb['open_month'] # calculate observe window
pivot_tb
# Out:
# MONTHS_BALANCE       ID  open_month  end_month  window
# ID
# 5001711         5001711          -3          0       3
# 5001712         5001712         -18          0      18
# 5001713         5001713         -21          0      21
# 5001714         5001714         -14          0      14
# 5001715         5001715         -59          0      59
# ...                 ...         ...        ...     ...
# 5150482         5150482         -28        -11      17
# 5150483         5150483         -17          0      17
# 5150484         5150484         -12          0      12
# 5150485         5150485          -1          0       1
# 5150487         5150487         -29          0      29
#
# [45985 rows x 4 columns]

# %%
pivot_tb.reset_index(drop = True, inplace = True)
credit = pd.merge(credit_record, pivot_tb, on = 'ID', how = 'left') # join calculated information
credit0 = credit.copy()
credit = credit[credit['window'] > 20] # delete users whose observe window less than 20
credit['status'] = np.where((credit['STATUS'] == '2') | (credit['STATUS'] == '3' )| (credit['STATUS'] == '4' )| (credit['STATUS'] == '5'), 1, 0) # analyze > 60 days past due 
credit['status'] = credit['status'].astype(np.int8) # 1: overdue 0: not
credit['month_on_book'] = credit['MONTHS_BALANCE'] - credit['open_month'] # calculate month on book: how many months after opening account
credit.sort_values(by = ['ID','month_on_book'], inplace = True)
credit
# Out:
#               ID  MONTHS_BALANCE STATUS  open_month  end_month  window  \
# 44       5001713             -21      X         -21          0      21
# 43       5001713             -20      X         -21          0      21
# 42       5001713             -19      X         -21          0      21
# 41       5001713             -18      X         -21          0      21
# 40       5001713             -17      X         -21          0      21
# ...          ...             ...    ...         ...        ...     ...
# 1048549  5150487              -4      C         -29          0      29
# 1048548  5150487              -3      C         -29          0      29
# 1048547  5150487              -2      C         -29          0      29
# 1048546  5150487              -1      C         -29          0      29
# 1048545  5150487               0      C         -29          0      29
#
#          status  month_on_book
# 44            0              0
# 43            0              1
# ...

# %%
df=application_record.merge(credit,on='ID')
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008806           M            Y               Y             0
# 1       5008806           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008806           M            Y               Y             0
# 4       5008806           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 549367  5149838           F            N               Y             0
# 549368  5149838           F            N               Y             0
# 549369  5149838           F            N               Y             0
# 549370  5149838           F            N               Y             0
# 549371  5149838           F            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df.ID.duplicated().sum()
# Out:
# 534206

# %%
df.drop_duplicates('ID',keep='last',inplace=True)

# %%
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008806           M            Y               Y             0
# 1      5008810           F            N               Y             0
# 2      5008811           F            N               Y             0
# 3      5112956           M            Y               Y             0
# 4      5008825           F            Y               N             0
# ...        ...         ...          ...             ...           ...
# 15161  5149145           M            Y               Y             0
# 15162  5149158           M            Y               Y             0
# 15163  5149729           M            Y               Y             0
# 15164  5149834           F            N               Y             0
# 15165  5149838           F            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
pd.pivot(data=df,columns='FLAG_OWN_REALTY',values='AMT_INCOME_TOTAL')
# Out:
# FLAG_OWN_REALTY         N         Y
# 0                     NaN  112500.0
# 1                     NaN  270000.0
# 2                     NaN  270000.0
# 3                     NaN  270000.0
# 4                130500.0       NaN
# ...                   ...       ...
# 15161                 NaN  247500.0
# 15162                 NaN  247500.0
# 15163                 NaN   90000.0
# 15164                 NaN  157500.0
# 15165                 NaN  157500.0
#
# [15166 rows x 2 columns]

# %%
df.AMT_INCOME_TOTAL.unique()
# Out:
# array([ 112500. ,  270000. ,  130500. ,  157500. ,  405000. ,  135000. ,
#         211500. ,  126000. ,  315000. ,  297000. ,  225000. ,  216000. ,
#         202500. ,  450000. ,  180000. ,   90000. ,  229500. ,  292500. ,
#          74250. ,  337500. ,  144000. ,  193500. ,  252000. ,  279000. ,
#          76500. ,  234000. ,  108000. ,  198000. ,   45000. ,  238500. ,
#         153000. , 1350000. ,  445500. ,  382500. ,   99000. ,  166500. ,
#          81000. ,  360000. ,  427500. ,  495000. ,   67500. ,  306000. ,
#         247500. ,  562500. ,  189000. ,  540000. ,  171000. ,  675000. ,
#         121500. ,   72000. ,   65250. ,  103500. ,  162000. ,  165150. ,
#         139500. ,   94500. ,  256500. ,   33300. ,   58500. ,  310500. ,
#         110250. ,  630000. ,  432000. ,  328500. ,  143100. ,  207000. ,
#         131400. ,   54000. ,  117000. ,  720000. ,   99900. ,  148500. ,
#          38250. ,  900000. ,   83250. ,   63000. ,  274500. ,   90900. ,
# ...

# %%
# >350000 1
#<350000 0
#>350000 and <=500000 2
#>500000 3
np.where(df.AMT_INCOME_TOTAL>350000,1,'upper_avg')
# Out:
# array(['upper_avg', 'upper_avg', 'upper_avg', ..., 'upper_avg',
#        'upper_avg', 'upper_avg'], dtype='<U11')

# %%
df.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS', 'MONTHS_BALANCE',
#        'STATUS', 'open_month', 'end_month', 'window', 'status',
#        'month_on_book'],
#       dtype='object')

# %%
df.AMT_INCOME_TOTAL.isna().sum()
# Out:
# 0

# %%
df[df.index==5008806]
# Out:
# Empty DataFrame
# Columns: [ID, CODE_GENDER, FLAG_OWN_CAR, FLAG_OWN_REALTY, CNT_CHILDREN, AMT_INCOME_TOTAL, NAME_INCOME_TYPE, NAME_EDUCATION_TYPE, NAME_FAMILY_STATUS, NAME_HOUSING_TYPE, DAYS_BIRTH, DAYS_EMPLOYED, FLAG_MOBIL, FLAG_WORK_PHONE, FLAG_PHONE, FLAG_EMAIL, OCCUPATION_TYPE, CNT_FAM_MEMBERS, MONTHS_BALANCE, STATUS, open_month, end_month, window, status, month_on_book]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ### Since everyone has a mobile we can drop it, ie the value is only 1

# %%
df.drop('FLAG_MOBIL',inplace=True,axis=1)

# %%
df.shape
# Out:
# (15166, 24)

# %%
df.FLAG_OWN_REALTY.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df.FLAG_OWN_CAR.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df.FLAG_EMAIL.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.FLAG_PHONE.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.FLAG_WORK_PHONE.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
def box_plot(df,col) :
    sns.boxplot(data = df, y = col)
    plt.show()

# %%
boxplt_col = ["DAYS_BIRTH","DAYS_EMPLOYED","AMT_INCOME_TOTAL","CNT_FAM_MEMBERS","CNT_CHILDREN"]
for col in boxplt_col :
    box_plot(df,col)

# %%
df.DAYS_EMPLOYED.describe()
# Out:
# count     15166.000000
# mean      56989.955756
# std      135821.976193
# min      -15661.000000
# 25%       -3335.000000
# 50%       -1748.000000
# 75%        -451.000000
# max      365243.000000
# Name: DAYS_EMPLOYED, dtype: float64

# %%
365243/365
# Out:
# 1000.6657534246575

# %%
df[df.DAYS_EMPLOYED>0]['NAME_INCOME_TYPE'].unique()
# Out:
# array(['Pensioner'], dtype=object)

# %% [markdown]
# ## Unemployed people's income type is Pensioner and their occupation is unknown.

# %%
df[df.DAYS_EMPLOYED>0]['OCCUPATION_TYPE'].unique()
# Out:
# array([nan], dtype=object)

# %%
df.OCCUPATION_TYPE.unique()
# Out:
# array(['Security staff', 'Sales staff', 'Accountants', 'Laborers', nan,
#        'Managers', 'Drivers', 'Core staff', 'Cleaning staff',
#        'High skill tech staff', 'Cooking staff', 'Medicine staff',
#        'Secretaries', 'Waiters/barmen staff', 'Low-skill Laborers',
#        'HR staff', 'Private service staff', 'Realty agents', 'IT staff'],
#       dtype=object)

# %%
df.fillna('Others',inplace=True)

# %%
df.OCCUPATION_TYPE.unique()
# Out:
# array(['Security staff', 'Sales staff', 'Accountants', 'Laborers',
#        'Others', 'Managers', 'Drivers', 'Core staff', 'Cleaning staff',
#        'High skill tech staff', 'Cooking staff', 'Medicine staff',
#        'Secretaries', 'Waiters/barmen staff', 'Low-skill Laborers',
#        'HR staff', 'Private service staff', 'Realty agents', 'IT staff'],
#       dtype=object)

# %%
df[df.DAYS_EMPLOYED>0]['OCCUPATION_TYPE'].unique()
# Out:
# array(['Others'], dtype=object)

# %%
df['Age']=(df.DAYS_BIRTH*-1)/365

# %%
df.Age=df.Age.astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15166 entries, 0 to 15165
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   15166 non-null  int64
#  1   CODE_GENDER          15166 non-null  object
#  2   FLAG_OWN_CAR         15166 non-null  object
#  3   FLAG_OWN_REALTY      15166 non-null  object
#  4   CNT_CHILDREN         15166 non-null  int64
#  5   AMT_INCOME_TOTAL     15166 non-null  float64
#  6   NAME_INCOME_TYPE     15166 non-null  object
#  7   NAME_EDUCATION_TYPE  15166 non-null  object
#  8   NAME_FAMILY_STATUS   15166 non-null  object
#  9   NAME_HOUSING_TYPE    15166 non-null  object
#  10  DAYS_BIRTH           15166 non-null  int64
#  11  DAYS_EMPLOYED        15166 non-null  int64
#  12  FLAG_WORK_PHONE      15166 non-null  int64
#  13  FLAG_PHONE           15166 non-null  int64
#  14  FLAG_EMAIL           15166 non-null  int64
# ...

# %%
df[df.DAYS_EMPLOYED>0]['Age'].describe()
# Out:
# count    2465.000000
# mean       59.245842
# std         5.200642
# min        26.000000
# 25%        57.000000
# 50%        60.000000
# 75%        63.000000
# max        68.000000
# Name: Age, dtype: float64

# %%
c=df.loc[(df['Age']>=26) & (df['Age']<=57)]

# %%
c[c.DAYS_EMPLOYED>0]['Age'].value_counts()
# Out:
# 57    196
# 56    149
# 55    119
# 54     62
# 53     62
# 52     40
# 51     36
# 50     15
# 46     11
# 45     10
# 47     10
# 42      9
# 44      8
# 39      6
# 27      6
# 49      5
# 40      5
# 48      4
# 41      2
# 37      2
# 26      2
# 43      1
# 36      1
# 32      1
# 30      1
# 28      1
# Name: Age, dtype: int64

# %% [markdown]
# ## # 1: overdue 0: not

# %%
df.groupby(['FLAG_OWN_CAR','STATUS']).agg({'ID': 'count'})
# Out:
#                        ID
# FLAG_OWN_CAR STATUS
# N            0       9091
#              1         47
# Y            0       5992
#              1         36

# %% [markdown]
# ## People that own a car their status overdue is comparitively less than not owning a car

# %%
df.drop('status',inplace=True,axis=1)

# %%
df.groupby(['FLAG_OWN_REALTY','STATUS']).agg({'ID': 'count'})
# Out:
#                           ID
# FLAG_OWN_REALTY STATUS
# N               0       5238
#                 1         28
# Y               0       9845
#                 1         55

# %% [markdown]
# ## People that own a realty their status overdue is comparitively more than not owning a car (1-overdue)

# %%
df.groupby(['FLAG_OWN_REALTY','STATUS']).agg({'ID': 'count'}).unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='FLAG_OWN_REALTY'>

# %%
df.open_month=df.open_month*-1

# %%
df.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL',
#        'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS', 'MONTHS_BALANCE', 'STATUS',
#        'open_month', 'end_month', 'window', 'month_on_book', 'Age'],
#       dtype='object')

# %%
df.drop('DAYS_BIRTH',inplace=True,axis=1)

# %%
#FOR CNT_FAM_MEMBERS COLUMN
q_hi = app['CNT_FAM_MEMBERS'].quantile(0.999)
q_low = app['CNT_FAM_MEMBERS'].quantile(0.001)
app= app[(app['CNT_FAM_MEMBERS']>q_low) & (app['CNT_FAM_MEMBERS']<q_hi)]

# %%
df.groupby(['NAME_FAMILY_STATUS','STATUS']).agg({'ID': 'count'})
# Out:
#                                 ID
# NAME_FAMILY_STATUS   STATUS
# Civil marriage       0        1131
#                      1           4
# Married              0       10739
#                      1          63
# Separated            0         876
#                      1           4
# Single / not married 0        1745
#                      1           9
# Widow                0         592
#                      1           3

# %%
df.groupby(['CNT_CHILDREN','STATUS']).agg({'ID': 'count'})
# Out:
#                         ID
# CNT_CHILDREN STATUS
# 0            0       10463
#              1          53
# 1            0        3009
#              1          21
# 2            0        1390
#              1           8
# 3            0         187
#              1           1
# 4            0          23
# 5            0           7
# 7            0           2
# 14           0           2

# %%
df.groupby(['NAME_EDUCATION_TYPE','STATUS']).agg({'ID': 'count'})
# Out:
#                                          ID
# NAME_EDUCATION_TYPE           STATUS
# Academic degree               0          18
# Higher education              0        4181
#                               1          20
# Incomplete higher             0         574
#                               1           6
# Lower secondary               0         169
#                               1           1
# Secondary / secondary special 0       10141
#                               1          56

# %% [markdown]
# ## Higher education ppl take loan more, overdue max-Secondary

# %%
df.groupby(['OCCUPATION_TYPE','STATUS']).agg({'ID': 'count'})
# Out:
#                                 ID
# OCCUPATION_TYPE       STATUS
# Accountants           0        502
#                       1          1
# Cleaning staff        0        212
#                       1          1
# Cooking staff         0        258
#                       1          1
# Core staff            0       1513
#                       1          4
# Drivers               0        952
#                       1          3
# HR staff              0         30
# High skill tech staff 0        654
#                       1          5
# IT staff              0         27
# Laborers              0       2545
#                       1         12
# Low-skill Laborers    0         63
#                       1          1
# Managers              0       1326
#                       1         12
# Medicine staff        0        547
#                       1          3
# Others                0       4632
#                       1         22
# Private service staff 0        120
# ...

# %% [markdown]
# ## Maximum laborers and managers take loan, IT staff take less loan
